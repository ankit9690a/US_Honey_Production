# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\ankit\\05th_Mar'

# %%
df=pd.read_csv('US_honey_dataset.csv')
df
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1115 non-null   int64
#  1   state                1115 non-null   object
#  2   colonies_number      1115 non-null   int64
#  3   yield_per_colony     1115 non-null   int64
#  4   production           1115 non-null   int64
#  5   stocks               1115 non-null   int64
#  6   average_price        1115 non-null   float64
#  7   value_of_production  1115 non-null   int64
#  8   year                 1115 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 78.5+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# state                  0
# colonies_number        0
# yield_per_colony       0
# production             0
# stocks                 0
# average_price          0
# value_of_production    0
# year                   0
# dtype: int64

# %%
df=df.dropna()

# %%
df.head()
# Out:
#    Unnamed: 0       state  colonies_number  yield_per_colony  production  \
# 0           0     Alabama            16000                58      928000
# 1           1     Arizona            52000                79     4108000
# 2           2    Arkansas            50000                60     3000000
# 3           3  California           420000                93    39060000
# 4           4    Colorado            45000                60     2700000
#
#     stocks  average_price  value_of_production  year
# 0    28000           62.0               575000  1995
# 1   986000           68.0              2793000  1995
# 2   900000           64.0              1920000  1995
# 3  4687000           60.0             23436000  1995
# 4  1404000           68.0              1836000  1995

# %% [markdown]
# ### drop unnamed column

# %%
df=df.drop(['Unnamed: 0'],axis=1)
df
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# ...

# %%
df.describe()
# Out:
#        colonies_number  yield_per_colony    production        stocks  \
# count      1115.000000       1115.000000  1.115000e+03  1.115000e+03
# mean      62438.565022         59.743498  2.851268e+06  1.172625e+06
# std       92648.175955         19.940500  5.561202e+06  2.049556e+06
# min        2000.000000         19.000000  1.200000e+04  9.000000e+03
# 25%        9000.000000         45.000000  2.460000e+05  1.125000e+05
# 50%       26000.000000         57.000000  8.280000e+05  3.700000e+05
# 75%       69000.000000         71.000000  2.700000e+06  1.253500e+06
# max      550000.000000        155.000000  3.906000e+07  1.354500e+07
#
#        average_price  value_of_production         year
# count    1115.000000         1.115000e+03  1115.000000
# mean      140.623076         5.667412e+06  2007.740807
# std       107.011544         9.459460e+06     7.823002
# min         1.300000         1.060000e+05  1995.000000
# 25%        70.000000         1.008000e+06  2001.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                1115 non-null   object
#  1   colonies_number      1115 non-null   int64
#  2   yield_per_colony     1115 non-null   int64
#  3   production           1115 non-null   int64
#  4   stocks               1115 non-null   int64
#  5   average_price        1115 non-null   float64
#  6   value_of_production  1115 non-null   int64
#  7   year                 1115 non-null   int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 69.8+ KB

# %% [markdown]
# #### renaming any columns

# %%
df=df.rename(columns={'yield_per_colony':'HoneyBee_yield_per_colony'})
df
# Out:
#              state  colonies_number  HoneyBee_yield_per_colony  production  \
# 0          Alabama            16000                         58      928000
# 1          Arizona            52000                         79     4108000
# 2         Arkansas            50000                         60     3000000
# 3       California           420000                         93    39060000
# 4         Colorado            45000                         60     2700000
# ...            ...              ...                        ...         ...
# 1110      Virginia             6000                         40       79000
# 1111    Washington            96000                         32     1206000
# 1112  WestVirginia             6000                         43      136000
# 1113     Wisconsin            42000                         47      750000
# 1114       Wyoming            38000                         58      242000
#
#        stocks  average_price  value_of_production  year
# ...

# %%
df.describe()
# Out:
#        colonies_number  HoneyBee_yield_per_colony    production        stocks  \
# count      1115.000000                1115.000000  1.115000e+03  1.115000e+03
# mean      62438.565022                  59.743498  2.851268e+06  1.172625e+06
# std       92648.175955                  19.940500  5.561202e+06  2.049556e+06
# min        2000.000000                  19.000000  1.200000e+04  9.000000e+03
# 25%        9000.000000                  45.000000  2.460000e+05  1.125000e+05
# 50%       26000.000000                  57.000000  8.280000e+05  3.700000e+05
# 75%       69000.000000                  71.000000  2.700000e+06  1.253500e+06
# max      550000.000000                 155.000000  3.906000e+07  1.354500e+07
#
#        average_price  value_of_production         year
# count    1115.000000         1.115000e+03  1115.000000
# mean      140.623076         5.667412e+06  2007.740807
# std       107.011544         9.459460e+06     7.823002
# ...

# %% [markdown]
# ##### df.to_excel('Newfile.xlsx',index=False)  # creating or modify a new excell file with modify or updated data

# %%
df.isnull().sum()
# Out:
# state                        0
# colonies_number              0
# HoneyBee_yield_per_colony    0
# production                   0
# stocks                       0
# average_price                0
# value_of_production          0
# year                         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#              state  colonies_number  HoneyBee_yield_per_colony  production  \
# 0          Alabama            16000                         58      928000
# 1          Arizona            52000                         79     4108000
# 2         Arkansas            50000                         60     3000000
# 3       California           420000                         93    39060000
# 4         Colorado            45000                         60     2700000
# ...            ...              ...                        ...         ...
# 1110      Virginia             6000                         40       79000
# 1111    Washington            96000                         32     1206000
# 1112  WestVirginia             6000                         43      136000
# 1113     Wisconsin            42000                         47      750000
# 1114       Wyoming            38000                         58      242000
#
#        stocks  average_price  value_of_production  year
# ...

# %% [markdown]
# ### Q1) Which states are rarely contributing to honey production for the last 27 years?

# %%
df1=df['state'].value_counts(ascending=True)
df1
# Out:
# state
# Maryland          9
# Oklahoma          9
# SouthCarolina    12
# Nevada           15
# NewMexico        18
# Kentucky         26
# NewYork          27
# NorthCarolina    27
# NorthDakota      27
# Ohio             27
# Oregon           27
# Alabama          27
# SouthDakota      27
# Tennessee        27
# Texas            27
# Utah             27
# Vermont          27
# Virginia         27
# Washington       27
# WestVirginia     27
# NewJersey        27
# Pennsylvania     27
# Montana          27
# Wisconsin        27
# Arizona          27
# Arkansas         27
# California       27
# Colorado         27
# Florida          27
# Georgia          27
# Hawaii           27
# Idaho            27
# Nebraska         27
# Illinois         27
# Iowa             27
# Kansas           27
# Louisiana        27
# Maine            27
# Michigan         27
# Minnesota        27
# Mississippi      27
# Missouri         27
# Indiana          27
# Wyoming          27
# ...

# %% [markdown]
# ##### Maryland and Oklahoma rarely contributing in production

# %% [markdown]
# ### Q2) Which are the top 5 Honey producing states in the US?

# %%
df2=df.groupby('state').sum().sort_values(by='production',ascending=False).head()
df2['production']
# Out:
# state
# NorthDakota    513742000
# California     423876000
# SouthDakota    355726000
# Florida        280934000
# Montana        197173000
# Name: production, dtype: int64

# %%
#before visualizing in graphs we need to reset the indexing of new data i.e. df2
df2=df.groupby('state').sum().reset_index().sort_values(by='production',ascending=False).head()
df2['production']
# Out:
# 28    513742000
# 3     423876000
# 34    355726000
# 5     280934000
# 21    197173000
# Name: production, dtype: int64

# %%
sns.barplot(x=df2['state'],y=df2['production'])
plt.show()

# %% [markdown]
# ### Q3) What is the Change in mean Average price of Honey from 1995 to 2021?

# %%
df3=df.groupby('year').mean('average_price').reset_index()
df3
# Out:
#     year  colonies_number  HoneyBee_yield_per_colony    production  \
# 0   1995     59977.272727                  66.909091  4.778909e+06
# 1   1996     58181.818182                  70.068182  4.499886e+06
# 2   1997     59651.162791                  68.953488  4.445953e+06
# 3   1998     60883.720930                  69.953488  5.100488e+06
# 4   1999     62186.046512                  65.465116  4.757791e+06
# 5   2000     60860.465116                  67.534884  5.123721e+06
# 6   2001     58139.534884                  65.209302  4.311698e+06
# 7   2002     57181.818182                  67.272727  3.880273e+06
# 8   2003     58681.818182                  62.522727  4.107750e+06
# 9   2004     63325.000000                  65.025000  4.559475e+06
# 10  2005     58341.463415                  64.268293  4.240415e+06
# 11  2006     57926.829268                  61.853659  3.759024e+06
# 12  2007     59121.951220                  59.390244  3.600220e+06
# ...

# %%
74.840909-3.334250
# Out:
# 71.506659

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df3['year'],y=df3['average_price'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Q4) Which was the year when production of Honey in whole US was the highest?

# %%
df4=df.groupby('year').sum('production').reset_index().sort_values(by='production',ascending=False).head(1)
df4
# Out:
#    year  colonies_number  HoneyBee_yield_per_colony  production    stocks  \
# 5  2000          2617000                       2904   220320000  85888000
#
#    average_price  value_of_production
# 5         3398.0            131022000

# %%
#this is not the correct answere because this will show max year which is 2021
df4=df.groupby('year').sum('production').reset_index().sort_values(by='production',ascending=False).max()
df4
# Out:
# year                              2021.0
# colonies_number                2792000.0
# HoneyBee_yield_per_colony         3083.0
# production                   220320000.0
# stocks                        85888000.0
# average_price                    12111.0
# value_of_production          384483000.0
# dtype: float64

# %%
df4=df.groupby('year').sum('production').reset_index()#sort_values(by='production',ascending=False).head(1)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df4['year'],y=df4['production'])
plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.show()

# %% [markdown]
# ### Q5) From the above inference we get the production was highest in the year 2000, now let
#  infe rwhic hstat ewa shavin ghighes tcontributio ni ntha tyear

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df5['state'],y=df5['production'])
plt.xticks(rotation=90)
plt.show()

# %%
df5.sort_values(by='production',ascending=False).head(1)
# Out:
#            state  colonies_number  HoneyBee_yield_per_colony  production  \
# 245  NorthDakota           290000                        115    33350000
#
#        stocks  average_price  value_of_production  year
# 245  13340000           56.0             18676000  2000

# %%
df5=df[df['year']==2000]
df5
# Out:
#              state  colonies_number  HoneyBee_yield_per_colony  production  \
# 217        Alabama            16000                         78     1248000
# 218        Arizona            40000                         59     2360000
# 219       Arkansas            55000                         93     5115000
# 220     California           440000                         70    30800000
# 221       Colorado            29000                         60     1740000
# 222        Florida           232000                        105    24360000
# 223        Georgia            55000                         57     3135000
# 224         Hawaii             7000                        112      784000
# 225          Idaho           100000                         47     4700000
# 226       Illinois             8000                         61      488000
# 227        Indiana             8000                         65      520000
# ...

# %% [markdown]
# ### Q6) Which states have the highest no. of colonies in the year 2000?

# %%
df6=df[df['year']==2000]
df6

# %%
sns.barplot(x=df6['state'],y=df6['colonies_number'])
plt.xticks(rotation=90)
plt.show()

# %%
df6.sort_values(by='colonies_number',ascending=False).head(1)
# Out:
#           state  colonies_number  HoneyBee_yield_per_colony  production  \
# 220  California           440000                         70    30800000
#
#        stocks  average_price  value_of_production  year
# 220  11396000           58.0             17864000  2000

# %%
df6=df[df['year']==2000]
df6
# Out:
#              state  colonies_number  HoneyBee_yield_per_colony  production  \
# 217        Alabama            16000                         78     1248000
# 218        Arizona            40000                         59     2360000
# 219       Arkansas            55000                         93     5115000
# 220     California           440000                         70    30800000
# 221       Colorado            29000                         60     1740000
# 222        Florida           232000                        105    24360000
# 223        Georgia            55000                         57     3135000
# 224         Hawaii             7000                        112      784000
# 225          Idaho           100000                         47     4700000
# 226       Illinois             8000                         61      488000
# 227        Indiana             8000                         65      520000
# ...

# %%
df6.to_excel('Newfile.xlsx',index=False) # to get modified excel file
